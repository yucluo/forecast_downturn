# %% [markdown]
# # Applying algorithm to full dataset

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.deprecated.doc2vec import LabeledSentence
from gensim.models.word2vec import Word2Vec
from gensim.models.phrases import Phraser, Phrases
from gensim.parsing.porter import PorterStemmer
from gensim.parsing.preprocessing import STOPWORDS
from gensim.parsing.preprocessing import remove_stopwords
from string import digits

import pandas as pd
import numpy as np
import string
import re
import random 
import os
import csv
import pickle

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')

from sklearn import metrics
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier 
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import confusion_matrix, precision_recall_curve, plot_precision_recall_curve, auc, average_precision_score,classification_report, confusion_matrix, accuracy_score, average_precision_score, precision_score, f1_score, recall_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import cross_val_score, cross_validate, RepeatedStratifiedKFold, train_test_split,KFold, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier

from modAL.models import ActiveLearner
from modAL.uncertainty import uncertainty_sampling
from modAL.uncertainty import entropy_sampling
from modAL.density import information_density

from scipy.stats import entropy
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/carlyknight/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Training

# %%
#### preprocessing -------------------------------
punctuation_dictionary = {s:None for s in list(string.punctuation)}

punctuation_translator = str.maketrans(punctuation_dictionary)

stop_words = set(stopwords.words('english'))

# (remove punctuation, numbers, lowercase, stop words)
def text_cleaner_all(text, punctuation_translator):
    text = text.replace('c("', '')
    text = str(text).translate(punctuation_translator)
    text = text.lower()
    remove_digits = str.maketrans('', '', digits)
    text = text.translate(remove_digits)
    word_tokens = word_tokenize(text)
    filtered_text = [w for w in word_tokens if not w.lower() in stop_words]
    text = ' '.join(filtered_text)
    return(text)

# (remove punctuation, lowercase, stop words)
def text_cleaner_mod(text, punctuation_translator):
    text = text.replace('c("', '')
    text = str(text).translate(punctuation_translator)
    text = text.lower()
    word_tokens = word_tokenize(text)
    filtered_text = [w for w in word_tokens if not w.lower() in stop_words]
    text = ' '.join(filtered_text)
    return(text)

# (remove punctuation, lowercase)
def text_cleaner_min(text, punctuation_translator):
    text = text.replace('c("', '')
    text = str(text).translate(punctuation_translator)
    text = text.lower()
    return(text)

# %%
#data
clas_dat = pd.read_csv("/Users/carlyknight/Dropbox/PROJECTS/Forecasting Downturns/data/coded_sample_final.csv")
clas_dat = clas_dat.drop_duplicates()


clas_dat.shape
# Out:
# (1196, 5)

# %%
#clean
clas_dat["clean_text"] = clas_dat["text"].apply(lambda x: text_cleaner_all(x, punctuation_translator))

# find phrases
phrases1 = Phrases(map(lambda x: x.split(), clas_dat["clean_text"].tolist())) #bigram
phrases2 = Phrases(phrases1[map(lambda x: x.split(), clas_dat["clean_text"].tolist())]) #trigram
clas_dat["phrased_text"] = clas_dat["clean_text"].apply(lambda x: " ".join(phrases2[phrases1[x.split()]]))

# %%
# vectorize
vectorizer = CountVectorizer(min_df=5)
tfidfconverter = TfidfTransformer()

X = vectorizer.fit_transform(clas_dat["phrased_text"]).toarray()  
X_tf = tfidfconverter.fit_transform(X).toarray()

y = np.array(clas_dat['final_code'])

# %%
#training set
X_train, X_test, y_train, y_test = train_test_split(X_tf, y, test_size=0.2)

model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]

# define grid search
scoring = ['accuracy', 'precision']

grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats = 5, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring= ['accuracy', 'precision'],refit = "accuracy")
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best Accuracy: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
precisions = grid_result.cv_results_['mean_test_precision']
accuracys =  grid_result.cv_results_['mean_test_accuracy']
std_prec = grid_result.cv_results_['std_test_precision']
std_acc = grid_result.cv_results_['std_test_accuracy']
params = grid_result.cv_results_['params']

for prec, acc, param in zip(precisions, accuracys, params):
    print("Precision: %f (Accuracy: %f) with: %r" % (prec, acc, param))
# Out:
# Best Accuracy: 0.726930 using {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# Precision: 0.720995 (Accuracy: 0.711068) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# Precision: 0.720995 (Accuracy: 0.711068) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# Precision: 0.720794 (Accuracy: 0.711068) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Precision: 0.738717 (Accuracy: 0.721721) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# Precision: 0.738717 (Accuracy: 0.721721) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# Precision: 0.738204 (Accuracy: 0.721721) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# Precision: 0.773143 (Accuracy: 0.726721) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# Precision: 0.772927 (Accuracy: 0.726303) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# Precision: 0.772632 (Accuracy: 0.726930) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# Precision: 0.842146 (Accuracy: 0.672583) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# Precision: 0.842146 (Accuracy: 0.672583) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Precision: 0.840147 (Accuracy: 0.678228) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# Precision: 0.000000 (Accuracy: 0.518816) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# Precision: 0.000000 (Accuracy: 0.518816) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# Precision: 0.000000 (Accuracy: 0.518816) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1: ', f1_score(y_test, y_pred))
# Out:
# Accuracy:  0.75
# Precision:  0.782608695652174
# Recall:  0.6428571428571429
# F1:  0.7058823529411765

# %%
#save
import joblib
joblib.dump(grid_search.best_estimator_, '/Users/carlyknight/Dropbox/PROJECTS/Forecasting Downturns/data/best_estimator_1200-8-16-21.pkl')
# Out:
# ['/Users/carlyknight/Dropbox/PROJECTS/Forecasting Downturns/data/best_estimator_1200-8-16-21.pkl']

# %% [markdown]
# # Entire dataset

# %%
#open all files
fulldat = pd.read_csv("/Users/carlyknight/Dropbox/PROJECTS/Forecasting Downturns/data/all_text.csv")

# %%
#create a list of ys
y_pred = []

#iterate over the dataframe 1000 times (chunks of 200)
i=0
for chunk in np.array_split(fulldat, 1000):
    print("Working on chunk: ", str(i))
    
    #clean
    chunk["clean_text"] = chunk["text"].apply(lambda x: text_cleaner_all(x, punctuation_translator))
    
    #find phrases (this will take a long time)
    phrases1 = Phrases(map(lambda x: x.split(), chunk["clean_text"].tolist())) #bigram
    phrases2 = Phrases(phrases1[map(lambda x: x.split(), chunk["clean_text"].tolist())]) #trigram
    chunk["phrased_text"] = chunk["clean_text"].apply(lambda x: " ".join(phrases2[phrases1[x.split()]]))
    
    #vectorize
    X = vectorizer.transform(chunk["phrased_text"]).toarray()
    X_tf = tfidfconverter.transform(X).toarray()

    #predict
    ystar = grid_search.best_estimator_.predict(X_tf)
    y_pred.append(ystar)
    i+=1
# Out:
# Working on chunk:  0
# Working on chunk:  1
# Working on chunk:  2
# Working on chunk:  3
# Working on chunk:  4
# Working on chunk:  5
# Working on chunk:  6
# Working on chunk:  7
# Working on chunk:  8
# Working on chunk:  9
# Working on chunk:  10
# Working on chunk:  11
# Working on chunk:  12
# Working on chunk:  13
# Working on chunk:  14
# Working on chunk:  15
# Working on chunk:  16
# Working on chunk:  17
# Working on chunk:  18
# Working on chunk:  19
# Working on chunk:  20
# Working on chunk:  21
# Working on chunk:  22
# Working on chunk:  23
# Working on chunk:  24
# Working on chunk:  25
# Working on chunk:  26
# Working on chunk:  27
# Working on chunk:  28
# Working on chunk:  29
# Working on chunk:  30
# Working on chunk:  31
# Working on chunk:  32
# Working on chunk:  33
# Working on chunk:  34
# Working on chunk:  35
# Working on chunk:  36
# Working on chunk:  37
# Working on chunk:  38
# Working on chunk:  39
# Working on chunk:  40
# Working on chunk:  41
# Working on chunk:  42
# Working on chunk:  43
# Working on chunk:  44
# Working on chunk:  45
# Working on chunk:  46
# Working on chunk:  47
# Working on chunk:  48
# Working on chunk:  49
# Working on chunk:  50
# Working on chunk:  51
# Working on chunk:  52
# Working on chunk:  53
# Working on chunk:  54
# Working on chunk:  55
# Working on chunk:  56
# Working on chunk:  57
# Working on chunk:  58
# Working on chunk:  59
# Working on chunk:  60
# Working on chunk:  61
# Working on chunk:  62
# Working on chunk:  63
# Working on chunk:  64
# Working on chunk:  65
# Working on chunk:  66
# Working on chunk:  67
# Working on chunk:  68
# Working on chunk:  69
# Working on chunk:  70
# Working on chunk:  71
# Working on chunk:  72
# Working on chunk:  73
# Working on chunk:  74
# Working on chunk:  75
# Working on chunk:  76
# Working on chunk:  77
# Working on chunk:  78
# Working on chunk:  79
# Working on chunk:  80
# Working on chunk:  81
# Working on chunk:  82
# Working on chunk:  83
# Working on chunk:  84
# Working on chunk:  85
# Working on chunk:  86
# Working on chunk:  87
# Working on chunk:  88
# Working on chunk:  89
# Working on chunk:  90
# Working on chunk:  91
# Working on chunk:  92
# Working on chunk:  93
# Working on chunk:  94
# Working on chunk:  95
# Working on chunk:  96
# Working on chunk:  97
# Working on chunk:  98
# Working on chunk:  99
# Working on chunk:  100
# Working on chunk:  101
# Working on chunk:  102
# Working on chunk:  103
# Working on chunk:  104
# Working on chunk:  105
# Working on chunk:  106
# Working on chunk:  107
# Working on chunk:  108
# Working on chunk:  109
# Working on chunk:  110
# Working on chunk:  111
# Working on chunk:  112
# Working on chunk:  113
# Working on chunk:  114
# Working on chunk:  115
# Working on chunk:  116
# Working on chunk:  117
# Working on chunk:  118
# Working on chunk:  119
# Working on chunk:  120
# Working on chunk:  121
# Working on chunk:  122
# Working on chunk:  123
# Working on chunk:  124
# Working on chunk:  125
# Working on chunk:  126
# Working on chunk:  127
# Working on chunk:  128
# Working on chunk:  129
# Working on chunk:  130
# Working on chunk:  131
# Working on chunk:  132
# Working on chunk:  133
# Working on chunk:  134
# Working on chunk:  135
# Working on chunk:  136
# Working on chunk:  137
# Working on chunk:  138
# Working on chunk:  139
# Working on chunk:  140
# Working on chunk:  141
# Working on chunk:  142
# Working on chunk:  143
# Working on chunk:  144
# Working on chunk:  145
# Working on chunk:  146
# Working on chunk:  147
# Working on chunk:  148
# Working on chunk:  149
# Working on chunk:  150
# Working on chunk:  151
# Working on chunk:  152
# Working on chunk:  153
# Working on chunk:  154
# Working on chunk:  155
# Working on chunk:  156
# Working on chunk:  157
# Working on chunk:  158
# Working on chunk:  159
# Working on chunk:  160
# Working on chunk:  161
# Working on chunk:  162
# Working on chunk:  163
# Working on chunk:  164
# Working on chunk:  165
# Working on chunk:  166
# Working on chunk:  167
# Working on chunk:  168
# Working on chunk:  169
# Working on chunk:  170
# Working on chunk:  171
# Working on chunk:  172
# Working on chunk:  173
# Working on chunk:  174
# Working on chunk:  175
# Working on chunk:  176
# Working on chunk:  177
# Working on chunk:  178
# Working on chunk:  179
# Working on chunk:  180
# Working on chunk:  181
# Working on chunk:  182
# Working on chunk:  183
# Working on chunk:  184
# Working on chunk:  185
# Working on chunk:  186
# Working on chunk:  187
# Working on chunk:  188
# Working on chunk:  189
# Working on chunk:  190
# Working on chunk:  191
# Working on chunk:  192
# Working on chunk:  193
# Working on chunk:  194
# Working on chunk:  195
# Working on chunk:  196
# Working on chunk:  197
# Working on chunk:  198
# Working on chunk:  199
# Working on chunk:  200
# Working on chunk:  201
# Working on chunk:  202
# Working on chunk:  203
# Working on chunk:  204
# Working on chunk:  205
# Working on chunk:  206
# Working on chunk:  207
# Working on chunk:  208
# Working on chunk:  209
# Working on chunk:  210
# Working on chunk:  211
# Working on chunk:  212
# Working on chunk:  213
# Working on chunk:  214
# Working on chunk:  215
# Working on chunk:  216
# Working on chunk:  217
# Working on chunk:  218
# Working on chunk:  219
# Working on chunk:  220
# Working on chunk:  221
# Working on chunk:  222
# Working on chunk:  223
# Working on chunk:  224
# Working on chunk:  225
# Working on chunk:  226
# Working on chunk:  227
# Working on chunk:  228
# Working on chunk:  229
# Working on chunk:  230
# Working on chunk:  231
# Working on chunk:  232
# Working on chunk:  233
# Working on chunk:  234
# Working on chunk:  235
# Working on chunk:  236
# Working on chunk:  237
# Working on chunk:  238
# Working on chunk:  239
# Working on chunk:  240
# Working on chunk:  241
# Working on chunk:  242
# Working on chunk:  243
# Working on chunk:  244
# Working on chunk:  245
# Working on chunk:  246
# Working on chunk:  247
# Working on chunk:  248
# Working on chunk:  249
# Working on chunk:  250
# Working on chunk:  251
# Working on chunk:  252
# Working on chunk:  253
# Working on chunk:  254
# Working on chunk:  255
# Working on chunk:  256
# Working on chunk:  257
# Working on chunk:  258
# Working on chunk:  259
# Working on chunk:  260
# Working on chunk:  261
# Working on chunk:  262
# Working on chunk:  263
# Working on chunk:  264
# Working on chunk:  265
# Working on chunk:  266
# Working on chunk:  267
# Working on chunk:  268
# Working on chunk:  269
# Working on chunk:  270
# Working on chunk:  271
# Working on chunk:  272
# Working on chunk:  273
# Working on chunk:  274
# Working on chunk:  275
# Working on chunk:  276
# Working on chunk:  277
# Working on chunk:  278
# Working on chunk:  279
# Working on chunk:  280
# Working on chunk:  281
# Working on chunk:  282
# Working on chunk:  283
# Working on chunk:  284
# Working on chunk:  285
# Working on chunk:  286
# Working on chunk:  287
# Working on chunk:  288
# Working on chunk:  289
# Working on chunk:  290
# Working on chunk:  291
# Working on chunk:  292
# Working on chunk:  293
# Working on chunk:  294
# Working on chunk:  295
# Working on chunk:  296
# Working on chunk:  297
# Working on chunk:  298
# Working on chunk:  299
# Working on chunk:  300
# Working on chunk:  301
# Working on chunk:  302
# Working on chunk:  303
# Working on chunk:  304
# Working on chunk:  305
# Working on chunk:  306
# Working on chunk:  307
# Working on chunk:  308
# Working on chunk:  309
# Working on chunk:  310
# Working on chunk:  311
# Working on chunk:  312
# Working on chunk:  313
# Working on chunk:  314
# Working on chunk:  315
# Working on chunk:  316
# Working on chunk:  317
# Working on chunk:  318
# Working on chunk:  319
# Working on chunk:  320
# Working on chunk:  321
# Working on chunk:  322
# Working on chunk:  323
# Working on chunk:  324
# Working on chunk:  325
# Working on chunk:  326
# Working on chunk:  327
# Working on chunk:  328
# Working on chunk:  329
# Working on chunk:  330
# Working on chunk:  331
# Working on chunk:  332
# Working on chunk:  333
# Working on chunk:  334
# Working on chunk:  335
# Working on chunk:  336
# Working on chunk:  337
# Working on chunk:  338
# Working on chunk:  339
# Working on chunk:  340
# Working on chunk:  341
# Working on chunk:  342
# Working on chunk:  343
# Working on chunk:  344
# Working on chunk:  345
# Working on chunk:  346
# Working on chunk:  347
# Working on chunk:  348
# Working on chunk:  349
# Working on chunk:  350
# Working on chunk:  351
# Working on chunk:  352
# Working on chunk:  353
# Working on chunk:  354
# Working on chunk:  355
# Working on chunk:  356
# Working on chunk:  357
# Working on chunk:  358
# Working on chunk:  359
# Working on chunk:  360
# Working on chunk:  361
# Working on chunk:  362
# Working on chunk:  363
# Working on chunk:  364
# Working on chunk:  365
# Working on chunk:  366
# Working on chunk:  367
# Working on chunk:  368
# Working on chunk:  369
# Working on chunk:  370
# Working on chunk:  371
# Working on chunk:  372
# Working on chunk:  373
# Working on chunk:  374
# Working on chunk:  375
# Working on chunk:  376
# Working on chunk:  377
# Working on chunk:  378
# Working on chunk:  379
# Working on chunk:  380
# Working on chunk:  381
# Working on chunk:  382
# Working on chunk:  383
# Working on chunk:  384
# Working on chunk:  385
# Working on chunk:  386
# Working on chunk:  387
# Working on chunk:  388
# Working on chunk:  389
# Working on chunk:  390
# Working on chunk:  391
# Working on chunk:  392
# Working on chunk:  393
# Working on chunk:  394
# Working on chunk:  395
# Working on chunk:  396
# Working on chunk:  397
# Working on chunk:  398
# Working on chunk:  399
# Working on chunk:  400
# Working on chunk:  401
# Working on chunk:  402
# Working on chunk:  403
# Working on chunk:  404
# Working on chunk:  405
# Working on chunk:  406
# Working on chunk:  407
# Working on chunk:  408
# Working on chunk:  409
# Working on chunk:  410
# Working on chunk:  411
# Working on chunk:  412
# Working on chunk:  413
# Working on chunk:  414
# Working on chunk:  415
# Working on chunk:  416
# Working on chunk:  417
# Working on chunk:  418
# Working on chunk:  419
# Working on chunk:  420
# Working on chunk:  421
# Working on chunk:  422
# Working on chunk:  423
# Working on chunk:  424
# Working on chunk:  425
# Working on chunk:  426
# Working on chunk:  427
# Working on chunk:  428
# Working on chunk:  429
# Working on chunk:  430
# Working on chunk:  431
# Working on chunk:  432
# Working on chunk:  433
# Working on chunk:  434
# Working on chunk:  435
# Working on chunk:  436
# Working on chunk:  437
# Working on chunk:  438
# Working on chunk:  439
# Working on chunk:  440
# Working on chunk:  441
# Working on chunk:  442
# Working on chunk:  443
# Working on chunk:  444
# Working on chunk:  445
# Working on chunk:  446
# Working on chunk:  447
# Working on chunk:  448
# Working on chunk:  449
# Working on chunk:  450
# Working on chunk:  451
# Working on chunk:  452
# Working on chunk:  453
# Working on chunk:  454
# Working on chunk:  455
# Working on chunk:  456
# Working on chunk:  457
# Working on chunk:  458
# Working on chunk:  459
# Working on chunk:  460
# Working on chunk:  461
# Working on chunk:  462
# Working on chunk:  463
# Working on chunk:  464
# Working on chunk:  465
# Working on chunk:  466
# Working on chunk:  467
# Working on chunk:  468
# Working on chunk:  469
# Working on chunk:  470
# Working on chunk:  471
# Working on chunk:  472
# Working on chunk:  473
# Working on chunk:  474
# Working on chunk:  475
# Working on chunk:  476
# Working on chunk:  477
# Working on chunk:  478
# Working on chunk:  479
# Working on chunk:  480
# Working on chunk:  481
# Working on chunk:  482
# Working on chunk:  483
# Working on chunk:  484
# Working on chunk:  485
# Working on chunk:  486
# Working on chunk:  487
# Working on chunk:  488
# Working on chunk:  489
# Working on chunk:  490
# Working on chunk:  491
# Working on chunk:  492
# Working on chunk:  493
# Working on chunk:  494
# Working on chunk:  495
# Working on chunk:  496
# Working on chunk:  497
# Working on chunk:  498
# Working on chunk:  499
# Working on chunk:  500
# Working on chunk:  501
# Working on chunk:  502
# Working on chunk:  503
# Working on chunk:  504
# Working on chunk:  505
# Working on chunk:  506
# Working on chunk:  507
# Working on chunk:  508
# Working on chunk:  509
# Working on chunk:  510
# Working on chunk:  511
# Working on chunk:  512
# Working on chunk:  513
# Working on chunk:  514
# Working on chunk:  515
# Working on chunk:  516
# Working on chunk:  517
# Working on chunk:  518
# Working on chunk:  519
# Working on chunk:  520
# Working on chunk:  521
# Working on chunk:  522
# Working on chunk:  523
# Working on chunk:  524
# Working on chunk:  525
# Working on chunk:  526
# Working on chunk:  527
# Working on chunk:  528
# Working on chunk:  529
# Working on chunk:  530
# Working on chunk:  531
# Working on chunk:  532
# Working on chunk:  533
# Working on chunk:  534
# Working on chunk:  535
# Working on chunk:  536
# Working on chunk:  537
# Working on chunk:  538
# Working on chunk:  539
# Working on chunk:  540
# Working on chunk:  541
# Working on chunk:  542
# Working on chunk:  543
# Working on chunk:  544
# Working on chunk:  545
# Working on chunk:  546
# Working on chunk:  547
# Working on chunk:  548
# Working on chunk:  549
# Working on chunk:  550
# Working on chunk:  551
# Working on chunk:  552
# Working on chunk:  553
# Working on chunk:  554
# Working on chunk:  555
# Working on chunk:  556
# Working on chunk:  557
# Working on chunk:  558
# Working on chunk:  559
# Working on chunk:  560
# Working on chunk:  561
# Working on chunk:  562
# Working on chunk:  563
# Working on chunk:  564
# Working on chunk:  565
# Working on chunk:  566
# Working on chunk:  567
# Working on chunk:  568
# Working on chunk:  569
# Working on chunk:  570
# Working on chunk:  571
# Working on chunk:  572
# Working on chunk:  573
# Working on chunk:  574
# Working on chunk:  575
# Working on chunk:  576
# Working on chunk:  577
# Working on chunk:  578
# Working on chunk:  579
# Working on chunk:  580
# Working on chunk:  581
# Working on chunk:  582
# Working on chunk:  583
# Working on chunk:  584
# Working on chunk:  585
# Working on chunk:  586
# Working on chunk:  587
# Working on chunk:  588
# Working on chunk:  589
# Working on chunk:  590
# Working on chunk:  591
# Working on chunk:  592
# Working on chunk:  593
# Working on chunk:  594
# Working on chunk:  595
# Working on chunk:  596
# Working on chunk:  597
# Working on chunk:  598
# Working on chunk:  599
# Working on chunk:  600
# Working on chunk:  601
# Working on chunk:  602
# Working on chunk:  603
# Working on chunk:  604
# Working on chunk:  605
# Working on chunk:  606
# Working on chunk:  607
# Working on chunk:  608
# Working on chunk:  609
# Working on chunk:  610
# Working on chunk:  611
# Working on chunk:  612
# Working on chunk:  613
# Working on chunk:  614
# Working on chunk:  615
# Working on chunk:  616
# Working on chunk:  617
# Working on chunk:  618
# Working on chunk:  619
# Working on chunk:  620
# Working on chunk:  621
# Working on chunk:  622
# Working on chunk:  623
# Working on chunk:  624
# Working on chunk:  625
# Working on chunk:  626
# Working on chunk:  627
# Working on chunk:  628
# Working on chunk:  629
# Working on chunk:  630
# Working on chunk:  631
# Working on chunk:  632
# Working on chunk:  633
# Working on chunk:  634
# Working on chunk:  635
# Working on chunk:  636
# Working on chunk:  637
# Working on chunk:  638
# Working on chunk:  639
# Working on chunk:  640
# Working on chunk:  641
# Working on chunk:  642
# Working on chunk:  643
# Working on chunk:  644
# Working on chunk:  645
# Working on chunk:  646
# Working on chunk:  647
# Working on chunk:  648
# Working on chunk:  649
# Working on chunk:  650
# Working on chunk:  651
# Working on chunk:  652
# Working on chunk:  653
# Working on chunk:  654
# Working on chunk:  655
# Working on chunk:  656
# Working on chunk:  657
# Working on chunk:  658
# Working on chunk:  659
# Working on chunk:  660
# Working on chunk:  661
# Working on chunk:  662
# Working on chunk:  663
# Working on chunk:  664
# Working on chunk:  665
# Working on chunk:  666
# Working on chunk:  667
# Working on chunk:  668
# Working on chunk:  669
# Working on chunk:  670
# Working on chunk:  671
# Working on chunk:  672
# Working on chunk:  673
# Working on chunk:  674
# Working on chunk:  675
# Working on chunk:  676
# Working on chunk:  677
# Working on chunk:  678
# Working on chunk:  679
# Working on chunk:  680
# Working on chunk:  681
# Working on chunk:  682
# Working on chunk:  683
# Working on chunk:  684
# Working on chunk:  685
# Working on chunk:  686
# Working on chunk:  687
# Working on chunk:  688
# Working on chunk:  689
# Working on chunk:  690
# Working on chunk:  691
# Working on chunk:  692
# Working on chunk:  693
# Working on chunk:  694
# Working on chunk:  695
# Working on chunk:  696
# Working on chunk:  697
# Working on chunk:  698
# Working on chunk:  699
# Working on chunk:  700
# Working on chunk:  701
# Working on chunk:  702
# Working on chunk:  703
# Working on chunk:  704
# Working on chunk:  705
# Working on chunk:  706
# Working on chunk:  707
# Working on chunk:  708
# Working on chunk:  709
# Working on chunk:  710
# Working on chunk:  711
# Working on chunk:  712
# Working on chunk:  713
# Working on chunk:  714
# Working on chunk:  715
# Working on chunk:  716
# Working on chunk:  717
# Working on chunk:  718
# Working on chunk:  719
# Working on chunk:  720
# Working on chunk:  721
# Working on chunk:  722
# Working on chunk:  723
# Working on chunk:  724
# Working on chunk:  725
# Working on chunk:  726
# Working on chunk:  727
# Working on chunk:  728
# Working on chunk:  729
# Working on chunk:  730
# Working on chunk:  731
# Working on chunk:  732
# Working on chunk:  733
# Working on chunk:  734
# Working on chunk:  735
# Working on chunk:  736
# Working on chunk:  737
# Working on chunk:  738
# Working on chunk:  739
# Working on chunk:  740
# Working on chunk:  741
# Working on chunk:  742
# Working on chunk:  743
# Working on chunk:  744
# Working on chunk:  745
# Working on chunk:  746
# Working on chunk:  747
# Working on chunk:  748
# Working on chunk:  749
# Working on chunk:  750
# Working on chunk:  751
# Working on chunk:  752
# Working on chunk:  753
# Working on chunk:  754
# Working on chunk:  755
# Working on chunk:  756
# Working on chunk:  757
# Working on chunk:  758
# Working on chunk:  759
# Working on chunk:  760
# Working on chunk:  761
# Working on chunk:  762
# Working on chunk:  763
# Working on chunk:  764
# Working on chunk:  765
# Working on chunk:  766
# Working on chunk:  767
# Working on chunk:  768
# Working on chunk:  769
# Working on chunk:  770
# Working on chunk:  771
# Working on chunk:  772
# Working on chunk:  773
# Working on chunk:  774
# Working on chunk:  775
# Working on chunk:  776
# Working on chunk:  777
# Working on chunk:  778
# Working on chunk:  779
# Working on chunk:  780
# Working on chunk:  781
# Working on chunk:  782
# Working on chunk:  783
# Working on chunk:  784
# Working on chunk:  785
# Working on chunk:  786
# Working on chunk:  787
# Working on chunk:  788
# Working on chunk:  789
# Working on chunk:  790
# Working on chunk:  791
# Working on chunk:  792
# Working on chunk:  793
# Working on chunk:  794
# Working on chunk:  795
# Working on chunk:  796
# Working on chunk:  797
# Working on chunk:  798
# Working on chunk:  799
# Working on chunk:  800
# Working on chunk:  801
# Working on chunk:  802
# Working on chunk:  803
# Working on chunk:  804
# Working on chunk:  805
# Working on chunk:  806
# Working on chunk:  807
# Working on chunk:  808
# Working on chunk:  809
# Working on chunk:  810
# Working on chunk:  811
# Working on chunk:  812
# Working on chunk:  813
# Working on chunk:  814
# Working on chunk:  815
# Working on chunk:  816
# Working on chunk:  817
# Working on chunk:  818
# Working on chunk:  819
# Working on chunk:  820
# Working on chunk:  821
# Working on chunk:  822
# Working on chunk:  823
# Working on chunk:  824
# Working on chunk:  825
# Working on chunk:  826
# Working on chunk:  827
# Working on chunk:  828
# Working on chunk:  829
# Working on chunk:  830
# Working on chunk:  831
# Working on chunk:  832
# Working on chunk:  833
# Working on chunk:  834
# Working on chunk:  835
# Working on chunk:  836
# Working on chunk:  837
# Working on chunk:  838
# Working on chunk:  839
# Working on chunk:  840
# Working on chunk:  841
# Working on chunk:  842
# Working on chunk:  843
# Working on chunk:  844
# Working on chunk:  845
# Working on chunk:  846
# Working on chunk:  847
# Working on chunk:  848
# Working on chunk:  849
# Working on chunk:  850
# Working on chunk:  851
# Working on chunk:  852
# Working on chunk:  853
# Working on chunk:  854
# Working on chunk:  855
# Working on chunk:  856
# Working on chunk:  857
# Working on chunk:  858
# Working on chunk:  859
# Working on chunk:  860
# Working on chunk:  861
# Working on chunk:  862
# Working on chunk:  863
# Working on chunk:  864
# Working on chunk:  865
# Working on chunk:  866
# Working on chunk:  867
# Working on chunk:  868
# Working on chunk:  869
# Working on chunk:  870
# Working on chunk:  871
# Working on chunk:  872
# Working on chunk:  873
# Working on chunk:  874
# Working on chunk:  875
# Working on chunk:  876
# Working on chunk:  877
# Working on chunk:  878
# Working on chunk:  879
# Working on chunk:  880
# Working on chunk:  881
# Working on chunk:  882
# Working on chunk:  883
# Working on chunk:  884
# Working on chunk:  885
# Working on chunk:  886
# Working on chunk:  887
# Working on chunk:  888
# Working on chunk:  889
# Working on chunk:  890
# Working on chunk:  891
# Working on chunk:  892
# Working on chunk:  893
# Working on chunk:  894
# Working on chunk:  895
# Working on chunk:  896
# Working on chunk:  897
# Working on chunk:  898
# Working on chunk:  899
# Working on chunk:  900
# Working on chunk:  901
# Working on chunk:  902
# Working on chunk:  903
# Working on chunk:  904
# Working on chunk:  905
# Working on chunk:  906
# Working on chunk:  907
# Working on chunk:  908
# Working on chunk:  909
# Working on chunk:  910
# Working on chunk:  911
# Working on chunk:  912
# Working on chunk:  913
# Working on chunk:  914
# Working on chunk:  915
# Working on chunk:  916
# Working on chunk:  917
# Working on chunk:  918
# Working on chunk:  919
# Working on chunk:  920
# Working on chunk:  921
# Working on chunk:  922
# Working on chunk:  923
# Working on chunk:  924
# Working on chunk:  925
# Working on chunk:  926
# Working on chunk:  927
# Working on chunk:  928
# Working on chunk:  929
# Working on chunk:  930
# Working on chunk:  931
# Working on chunk:  932
# Working on chunk:  933
# Working on chunk:  934
# Working on chunk:  935
# Working on chunk:  936
# Working on chunk:  937
# Working on chunk:  938
# Working on chunk:  939
# Working on chunk:  940
# Working on chunk:  941
# Working on chunk:  942
# Working on chunk:  943
# Working on chunk:  944
# Working on chunk:  945
# Working on chunk:  946
# Working on chunk:  947
# Working on chunk:  948
# Working on chunk:  949
# Working on chunk:  950
# Working on chunk:  951
# Working on chunk:  952
# Working on chunk:  953
# Working on chunk:  954
# Working on chunk:  955
# Working on chunk:  956
# Working on chunk:  957
# Working on chunk:  958
# Working on chunk:  959
# Working on chunk:  960
# Working on chunk:  961
# Working on chunk:  962
# Working on chunk:  963
# Working on chunk:  964
# Working on chunk:  965
# Working on chunk:  966
# Working on chunk:  967
# Working on chunk:  968
# Working on chunk:  969
# Working on chunk:  970
# Working on chunk:  971
# Working on chunk:  972
# Working on chunk:  973
# Working on chunk:  974
# Working on chunk:  975
# Working on chunk:  976
# Working on chunk:  977
# Working on chunk:  978
# Working on chunk:  979
# Working on chunk:  980
# Working on chunk:  981
# Working on chunk:  982
# Working on chunk:  983
# Working on chunk:  984
# Working on chunk:  985
# Working on chunk:  986
# Working on chunk:  987
# Working on chunk:  988
# Working on chunk:  989
# Working on chunk:  990
# Working on chunk:  991
# Working on chunk:  992
# Working on chunk:  993
# Working on chunk:  994
# Working on chunk:  995
# Working on chunk:  996
# Working on chunk:  997
# Working on chunk:  998
# Working on chunk:  999

# %%
#add column
y_pred_list = [item for items in y_pred for item in items]
fulldat['prediction'] = y_pred_list

#keep id and prediction and output
output = fulldat[["id", "prediction"]]
output.to_csv("/Users/carlyknight/Dropbox/PROJECTS/Forecasting Downturns/data/text_predictions_8-19-21.csv")
